# %% [markdown]
# ***Theory Queations***

# %% [markdown]
# # Question 1: What is a Support Vector Machine (SVM)?
# Ans:
# SVM is a supervised machine learning algorithm used for classification and regression tasks.
# It finds the best line (in 2D) or hyperplane (in higher dimensions) that separates data into different classes.
# The main goal is to maximize the margin — the distance between the separating line and the nearest data points of each class.

# %% [markdown]
# # Question 2: What is the difference between Hard Margin and Soft Margin SVM?
# Ans:
# | Type                | Meaning                                                            | When to Use                                     |
# | ------------------- | ------------------------------------------------------------------ | ----------------------------------------------- |
# | **Hard Margin SVM** | Tries to perfectly separate the data with no mistakes.             | When data is **linearly separable** (no noise). |
# | **Soft Margin SVM** | Allows some misclassification to handle noisy or overlapping data. | When data is **not perfectly separable**.       |

# %% [markdown]
# # Question 3: What is the mathematical intuition behind SVM?
# Ans:
# SVM tries to solve this:
#
# Maximize 2/||w||
#
#
#
# subject to:
#
# yi​(w⋅xi​+b)≥1
# Here:
# w = weight vector (defines the hyperplane)
# b = bias
# 𝑦𝑖=ylass label (+1 or -1)
# yi=y
# i
# 	​
#
#  = class label (+1 or -1)
# 	​
#
#  = class label (+1 or -1)
#
# 𝑥
# 𝑖
# x
# i
# 	​
#
#  = feature vector
#
# It means: find
# 𝑤
# w and
# 𝑏
# b that make the margin (distance between classes) as wide as possible.

# %% [markdown]
# # Queastion 4. What is the role of Lagrange Multipliers in SVM?
# Ans:
# Lagrange Multipliers help in optimizing the SVM problem using constrained optimization.
# They convert the problem into a dual form so that we can use only the dot product between samples — useful when applying the kernel trick.

# %% [markdown]
# # Queastions 5: What are Support Vectors in SVM?
#
# Answer:
# Support vectors are the data points closest to the hyperplane.
#
# They define the margin.
#
# Removing other points doesn’t change the hyperplane; only support vectors matter.

# %% [markdown]
# # Queations 6: What is a Support Vector Classifier (SVC)?
#
# Answer:
# SVC is an SVM used for classification tasks.
#
# It finds the hyperplane that separates classes with maximum margin.
#
# Can use kernels to handle non-linear data.

# %% [markdown]
# # Queastion 7: What is a Support Vector Regressor (SVR)?
#
# Answer:
# SVR is SVM for regression.
#
# Tries to fit a line (or hyperplane) that is within a margin
# 𝜖
# ϵ of actual data points.
#
# Ignores points within
# 𝜖
# ϵ margin, penalizes points outside the margin.

# %% [markdown]
# # Queastion 8: What is the Kernel Trick in SVM?
#
# Answer:
# SVM works in high-dimensional space to make data linearly separable.
#
# Kernel trick lets us compute inner products in high dimensions without explicit transformation.
#
# Common kernels: Linear, Polynomial, RBF (Gaussian).

# %% [markdown]
# # Queastion 9:Compare Linear Kernel, Polynomial Kernel, and RBF Kernel
# Ans:
# | Kernel         | Description                                   | Use Case                 |
# | -------------- | --------------------------------------------- | ------------------------ |
# | Linear         | No transformation, straight hyperplane        | Linearly separable data  |
# | Polynomial     | Projects data into polynomial space           | Non-linear boundaries    |
# | RBF (Gaussian) | Projects data into infinite-dimensional space | Complex, non-linear data |

# %% [markdown]
# # Queastion 10: What is the effect of the C parameter in SVM
# Ans:
# In Support Vector Machine (SVM), the C parameter is a regularization parameter that controls the trade-off between maximizing the margin and minimizing the classification error on the training data.
#
# A large value of C assigns a higher penalty to misclassification. The model tries to classify all training points correctly, resulting in a narrower margin and potentially overfitting the data.
#
# A small value of C allows some misclassifications in the training data, resulting in a wider margin. This helps the model generalize better and reduces sensitivity to noise.

# %% [markdown]
# # Queastion 11:  What is the role of the Gamma parameter in RBF Kernel SVM
# Ans:
# In SVM with the RBF (Radial Basis Function) kernel, the Gamma (γ) parameter defines the influence of a single training example on the decision boundary.
#
# - High Gamma (large γ):
#
# Each data point has a small area of influence.
#
# The decision boundary becomes more complex, closely fitting the training data.
#
# Can overfit the data.
#
# - Low Gamma (small γ):
#
# Each data point has a large area of influence.
#
# The decision boundary is smoother, less sensitive to individual points.
#
# Better generalization, but may underfit the data.

# %% [markdown]
# # Queastion 12: What is the Naïve Bayes classifier, and why is it called "Naïve"
# Ans:
# - Naïve Bayes Classifier:
#
# The Naïve Bayes classifier is a probabilistic machine learning algorithm used for classification tasks. It is based on Bayes’ Theorem, which calculates the probability of a class given the features of a data point.
#
# formula: P(Class∣Features)=P(Features)P(Features∣Class)⋅P(Class)/p(features)
#
#  P(Class|Features): Probability of the class given the features (posterior)
#
# (Features|Class): Probability of features given the class (likelihood)
#
# P(Class): Probability of the class (prior)
#
# P(Features): Probability of features (evidence)
#
# - Why is it called “Naïve”?
#
# It is called naïve because it assumes that all features are independent of each other, which is a simplification and often not true in real-world data.
#
# Despite this assumption, it works surprisingly well in many applications, especially text classification.
#
# - Key Points:
#
# Simple and fast
#
# Requires less training data
#
# Works well with high-dimensional data

# %% [markdown]
# # Queastions 13: What is Bayes’ Theorem
# Ans:
# - Bayes’ Theorem:
#
# Bayes’ Theorem is a mathematical formula used to calculate the probability of an event based on prior knowledge of conditions related to that event. It is the foundation of the Naïve Bayes classifier.
# formula = P(A∣B)=P(B)P(B∣A)⋅P(A)/P(B)
# Where:
# P(A∣B) = Probability of event A given that B has occurred (posterior probability)
# P(B∣A) = Probability of event B given that A has occurred (likelihood)
# P(A) = Probability of event A (prior probability)
# P(B) = Probability of event B (evidence)
#
# - Explanation:
#
# Bayes’ Theorem updates the probability of a hypothesis (A) when new evidence (B) is observed.
#
# It helps in making predictions or decisions based on prior knowledge and observed data.
#
# - Example:
#
# Suppose a patient may have a disease (A), and you know the probability of a positive test (B) if the patient has the disease. Bayes’ Theorem helps calculate the probability that the patient actually has the disease given a positive test result.

# %% [markdown]
# # Queastion 14: Explain the differences between Gaussian Naïve Bayes, Multinomial Naïve Bayes, and Bernoulli Naïve Bayes
# Ans:
# | Type                        | Feature Type        | Description                                                                                                                                  | Use Case                                                                                      |
# | --------------------------- | ------------------- | -------------------------------------------------------------------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------- |
# | **Gaussian Naïve Bayes**    | Continuous features | Assumes that **continuous features follow a normal (Gaussian) distribution**. Probability is calculated using mean and variance of features. | Predicting real-valued data like height, weight, or temperature.                              |
# | **Multinomial Naïve Bayes** | Discrete counts     | Assumes features are **discrete counts**, such as word frequencies.                                                                          | Text classification (spam detection, document classification) where features are word counts. |
# | **Bernoulli Naïve Bayes**   | Binary features     | Assumes features are **binary (0 or 1)**, indicating presence or absence of a feature.                                                       | Text classification (document classification) using presence/absence of words.                |

# %% [markdown]
# # Queastion 15: When should you use Gaussian Naïve Bayes over other variants
# Ans:
# - When to Use Gaussian Naïve Bayes:
#
# Gaussian Naïve Bayes is used when the features of your dataset are continuous and approximately normally (Gaussian) distributed.
#
# It calculates probabilities using the mean and variance of the features for each class.
#
# - Use Cases:
#
# Predicting real-valued measurements, such as height, weight, or temperature.
#
# Medical diagnosis where features are numeric test results.
#
# Any dataset where features are continuous rather than categorical.
#
# - Key Point:
#
# If your features are categorical or count-based, you should use Multinomial or Bernoulli Naïve Bayes instead.

# %% [markdown]
# # Queastion 16: What are the key assumptions made by Naïve Bayes
# Ans:
# Key Assumptions Made by Naïve Bayes:
#
# 1. Feature Independence:
#
# Naïve Bayes assumes that all features are independent of each other given the class label.
#
# Example: In email spam detection, it assumes the presence of one word does not affect the presence of another word.
#
# 2. Equal Importance of Features:
#
# All features contribute equally and independently to the outcome.
#
# There is no weighting based on feature importance.
#
# 3. Conditional Probability:
#
# The probability of each feature is computed conditionally on the class label.
#
# 4. Implications:
#
# This assumption simplifies calculations and makes the algorithm fast and efficient.
#
# However, if features are highly correlated, the independence assumption is violated, which may reduce accuracy.

# %% [markdown]
# # Queastion 17: What are the advantages and disadvantages of Naïve Bayes
# Ans:
# - Advantages of Naïve Bayes:
#
# Simple and Fast: Easy to implement and trains quickly even on large datasets.
#
# Works Well with High-Dimensional Data: Handles many features efficiently, such as text data with thousands of words.
#
# Requires Less Training Data: Can perform well even with a smaller dataset.
#
# Good for Text Classification: Performs very well in spam detection, sentiment analysis, and document classification.
#
# Probabilistic Output: Gives the probability of each class, which is useful for decision-making.
#
# - Disadvantages of Naïve Bayes:
#
# Assumes Feature Independence: Works poorly when features are highly correlated.
#
# Zero Probability Problem: If a feature never appears in the training set for a class, probability becomes zero (can be fixed with Laplace smoothing).
#
# Not Good for Complex Relationships: Cannot capture interactions between features well.
#
# Continuous Features Assumption: For Gaussian Naïve Bayes, assumes features are normally distributed, which may not always hold.

# %% [markdown]
# # Queastion 18: Why is Naïve Bayes a good choice for text classification
# Ans:
# 1 Handles High-Dimensional Data:
#
# Text data has thousands of features (words), and Naïve Bayes can process them efficiently.
#
# 2.Assumption of Feature Independence Works Well for Text:
#
#  ords are treated as independent features (bag-of-words model), which fits the algorithm’s assumptions.
#
# 3.Fast and Simple:
#
# Trains quickly even on large text datasets.
#
# 4.. Probabilistic Output:
#
# Gives the probability of a document belonging to each class, useful for ranking and decision-making.
#
# 5. Effective for Common Tasks:
#
# Works very well for spam detection, sentiment analysis, and document classification, even with relatively small training data.

# %% [markdown]
# # Queation 19: Compare SVM and Naïve Bayes for classification tasks
# Ans:
# | Feature                      | **SVM (Support Vector Machine)**                            | **Naïve Bayes**                                                |
# | ---------------------------- | ----------------------------------------------------------- | -------------------------------------------------------------- |
# | **Type**                     | Margin-based classifier                                     | Probabilistic classifier                                       |
# | **Assumption**               | No independence assumption; works with feature correlations | Assumes all features are independent                           |
# | **Data Handling**            | Can handle linear and non-linear data using kernels         | Works well with high-dimensional data but assumes independence |
# | **Speed**                    | Slower to train, especially on large datasets               | Fast to train, even on large datasets                          |
# | **Complexity**               | Can create complex decision boundaries                      | Simpler, less flexible decision boundaries                     |
# | **Noise Sensitivity**        | Sensitive to outliers and noise                             | More robust to noise due to probability modeling               |
# | **Text Classification**      | Works, but requires feature extraction and tuning           | Excellent for text, simple bag-of-words works well             |
# | **Overfitting/Underfitting** | Needs careful tuning of C, Gamma, and kernel                | Less prone to overfitting, simple model                        |

# %% [markdown]
# # Queastion 20: How does Laplace Smoothing help in Naïve Bayes?
# Ans:
# - How Laplace Smoothing Helps in Naïve Bayes:
#
# In Naïve Bayes, the probability of a feature given a class is calculated from training data.
#
# Sometimes, a feature may not appear in the training data for a class.
#
# Without smoothing, this gives a probability of 0, which makes the overall prediction zero when multiplying probabilities.
#
# - Laplace Smoothing (Add-1 Smoothing):
#
# Adds 1 to all feature counts to avoid zero probabilities.

# %% [markdown]
# ***Practical queastions:***

# %%
# Q 21: Write a Python program to train an SVM Classifier on the Iris dataset and evaluate accuracy
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load Iris dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train SVM Classifier
svm_model = SVC()
svm_model.fit(X_train, y_train)

# Predict and evaluate
y_pred = svm_model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
# Q 22: Write a Python program to train two SVM classifiers with Linear and RBF kernels on the Wine dataset, then compare their accuracies
from sklearn.datasets import load_wine

wine = load_wine()
X, y = wine.data, wine.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Linear Kernel
svm_linear = SVC(kernel='linear')
svm_linear.fit(X_train, y_train)
y_pred_linear = svm_linear.predict(X_test)
acc_linear = accuracy_score(y_test, y_pred_linear)

# RBF Kernel
svm_rbf = SVC(kernel='rbf')
svm_rbf.fit(X_train, y_train)
y_pred_rbf = svm_rbf.predict(X_test)
acc_rbf = accuracy_score(y_test, y_pred_rbf)

print("Linear Kernel Accuracy:", acc_linear)
print("RBF Kernel Accuracy:", acc_rbf)
# Out:
# Linear Kernel Accuracy: 0.9814814814814815
# RBF Kernel Accuracy: 0.7592592592592593

# %%
#Q.23: Write a Python program to train an SVM Regressor (SVR) on a housing dataset and evaluate it using Mean Squared Error (MSE)
from sklearn.datasets import fetch_california_housing
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()
X, y = housing.data, housing.target

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Train SVR
svr = SVR(kernel='rbf')
svr.fit(X_train, y_train)

y_pred = svr.predict(X_test)
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# MSE: 0.34705834034323335

# %%
# Q.24:Write a Python program to train an SVM Classifier with a Polynomial Kernel and visualize the decision boundary
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# Generate 2D dataset
X, y = make_classification(n_samples=200, n_features=2, n_classes=2, n_informative=2, n_redundant=0, random_state=42)

# Train Polynomial SVM
svm_poly = SVC(kernel='poly', degree=3)
svm_poly.fit(X, y)

# Plot decision boundary
xx, yy = np.meshgrid(np.linspace(X[:,0].min()-1, X[:,0].max()+1, 500),
                     np.linspace(X[:,1].min()-1, X[:,1].max()+1, 500))
Z = svm_poly.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.3)
plt.scatter(X[:,0], X[:,1], c=y, s=30)
plt.title("Polynomial Kernel SVM Decision Boundary")
plt.show()

# %%
# Q.25: Write a Python program to train a Gaussian Naïve Bayes classifier on the Breast Cancer dataset and evaluate accuracy
from sklearn.datasets import load_breast_cancer
from sklearn.naive_bayes import GaussianNB

cancer = load_breast_cancer()
X, y = cancer.data, cancer.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9415204678362573

# %%
# Q.26:Write a Python program to train a Multinomial Naïve Bayes classifier for text classification using the 20 Newsgroups dataset
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

categories = ['comp.graphics', 'sci.space', 'rec.sport.baseball']
newsgroups_train = fetch_20newsgroups(subset='train', categories=categories)
newsgroups_test = fetch_20newsgroups(subset='test', categories=categories)

vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(newsgroups_train.data)
X_test = vectorizer.transform(newsgroups_test.data)

mnb = MultinomialNB()
mnb.fit(X_train, newsgroups_train.target)
y_pred = mnb.predict(X_test)

print("Accuracy:", accuracy_score(newsgroups_test.target, y_pred))

# %%
# Q.27:Write a Python program to train an SVM Classifier with different C values and compare the decision boundaries visually
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Load dataset
X, y = datasets.make_classification(n_samples=200, n_features=2,
                                    n_redundant=0, n_informative=2,
                                    random_state=42, n_clusters_per_class=1)

# Scale features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Train SVM models with different C values
C_values = [0.1, 1, 10, 100]
models = []

for C in C_values:
    model = SVC(kernel='linear', C=C)
    model.fit(X, y)
    models.append(model)

# Plot decision boundaries
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200), np.linspace(y_min, y_max, 200))

for i, (ax, C, model) in enumerate(zip(axes, C_values, models)):
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=0.3)
    ax.scatter(X[:, 0], X[:, 1], c=y, s=30, edgecolors='k')
    ax.set_title(f'SVM with C={C}')

plt.tight_layout()
plt.show()

# %%
# Q.28: Write a Python program to train a Bernoulli Naïve Bayes classifier for binary classification on a dataset with binary features
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# Create binary dataset
X, y = make_classification(n_samples=500, n_features=10, n_informative=5, n_redundant=0,
                           n_classes=2, random_state=42)

# Convert features to binary (0 or 1)
X_binary = (X > 0).astype(int)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X_binary, y, test_size=0.3, random_state=42)

# Train Bernoulli Naïve Bayes classifier
model = BernoulliNB()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.81
#
# Confusion Matrix:
# [[52 19]
#  [10 69]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.73      0.78        71
#            1       0.78      0.87      0.83        79
#
#     accuracy                           0.81       150
#    macro avg       0.81      0.80      0.80       150
# weighted avg       0.81      0.81      0.81       150

# %%
#Q.29: Write a Python program to apply feature scaling before training an SVM model and compare results with unscaled data
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Load dataset
X, y = datasets.load_iris(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train SVM without scaling
model_unscaled = SVC(kernel='rbf')
model_unscaled.fit(X_train, y_train)
y_pred_unscaled = model_unscaled.predict(X_test)
unscaled_acc = accuracy_score(y_test, y_pred_unscaled)

# Apply feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train SVM with scaled data
model_scaled = SVC(kernel='rbf')
model_scaled.fit(X_train_scaled, y_train)
y_pred_scaled = model_scaled.predict(X_test_scaled)
scaled_acc = accuracy_score(y_test, y_pred_scaled)

# Compare results
print(f"Accuracy without scaling: {unscaled_acc:.3f}")
print(f"Accuracy with scaling: {scaled_acc:.3f}")
# Out:
# Accuracy without scaling: 1.000
# Accuracy with scaling: 1.000

# %%
#Q.30: Write a Python program to train a Gaussian Naïve Bayes model and compare the predictions before and after Laplace Smoothing
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Load dataset
X, y = load_iris(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Gaussian Naive Bayes without Laplace smoothing
model_no_smooth = GaussianNB(var_smoothing=1e-9)
model_no_smooth.fit(X_train, y_train)
y_pred_no_smooth = model_no_smooth.predict(X_test)
acc_no_smooth = accuracy_score(y_test, y_pred_no_smooth)

# Train Gaussian Naive Bayes with Laplace smoothing (higher var_smoothing)
model_smooth = GaussianNB(var_smoothing=1e-2)
model_smooth.fit(X_train, y_train)
y_pred_smooth = model_smooth.predict(X_test)
acc_smooth = accuracy_score(y_test, y_pred_smooth)

# Compare results
print(f"Accuracy without Laplace smoothing: {acc_no_smooth:.3f}")
print(f"Accuracy with Laplace smoothing: {acc_smooth:.3f}")
# Out:
# Accuracy without Laplace smoothing: 0.978
# Accuracy with Laplace smoothing: 1.000

# %%
# Q.31: Write a Python program to train an SVM Classifier and use GridSearchCV to tune the hyperparameters (C, gamma, kernel)
from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load dataset
X, y = datasets.load_iris(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define SVM and parameter grid
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto'],
    'kernel': ['linear', 'rbf', 'poly']
}

svc = SVC()
grid_search = GridSearchCV(svc, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Best parameters and score
print('Best hyperparameters:', grid_search.best_params_)
print('Best cross-validation accuracy:', grid_search.best_score_)

# Evaluate on test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
print('Test set accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Best hyperparameters: {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# Best cross-validation accuracy: 0.9714285714285715
# Test set accuracy: 0.9777777777777777

# %%
# Q.32: Write a Python program to train an SVM Classifier on an imbalanced dataset and apply class weighting and check it improve accuracy
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Create an imbalanced dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5,
                           n_redundant=0, n_classes=2, weights=[0.9, 0.1],
                           random_state=42)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Train SVM without class weighting
model_no_weight = SVC(kernel='linear')
model_no_weight.fit(X_train, y_train)
y_pred_no_weight = model_no_weight.predict(X_test)
acc_no_weight = accuracy_score(y_test, y_pred_no_weight)

# Train SVM with class weighting
model_weighted = SVC(kernel='linear', class_weight='balanced')
model_weighted.fit(X_train, y_train)
y_pred_weighted = model_weighted.predict(X_test)
acc_weighted = accuracy_score(y_test, y_pred_weighted)

# Compare results
print(f"Accuracy without class weighting: {acc_no_weight:.3f}")
print(f"Accuracy with class weighting: {acc_weighted:.3f}")
print("\nClassification Report (weighted SVM):")
print(classification_report(y_test, y_pred_weighted))
# Out:
# Accuracy without class weighting: 0.927
# Accuracy with class weighting: 0.780
#
# Classification Report (weighted SVM):
#               precision    recall  f1-score   support
#
#            0       0.99      0.77      0.86       269
#            1       0.31      0.90      0.46        31
#
#     accuracy                           0.78       300
#    macro avg       0.65      0.83      0.66       300
# weighted avg       0.92      0.78      0.82       300

# %%
# Q.33: Write a Python program to implement a Naïve Bayes classifier for spam detection using email data
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report

# Example email dataset
emails = [
    'Free money now!!!',
    'Hi, how are you?',
    'Congratulations, you won a prize',
    'Let\'s meet for lunch',
    'Claim your free gift today',
    'Can we discuss the project tomorrow?',
    'Win a free iPhone now',
    'Are you attending the meeting?'
]
labels = [1, 0, 1, 0, 1, 0, 1, 0]  # 1 = spam, 0 = not spam

# Convert text to numerical features
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(emails)
y = labels

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Train Naive Bayes classifier
model = MultinomialNB()
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.00
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       2.0
#            1       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
# C:\Users\KOMAL\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\KOMAL\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Q.34: Write a Python program to train an SVM Classifier and a Naïve Bayes Classifier on the same dataset and compare their accuracy
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Load dataset
X, y = datasets.load_iris(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train SVM classifier
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)
svm_acc = accuracy_score(y_test, y_pred_svm)

# Train Naive Bayes classifier
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
y_pred_nb = nb_model.predict(X_test)
nb_acc = accuracy_score(y_test, y_pred_nb)

# Compare accuracies
print(f"SVM Accuracy: {svm_acc:.3f}")
print(f"Naive Bayes Accuracy: {nb_acc:.3f}")
# Out:
# SVM Accuracy: 1.000
# Naive Bayes Accuracy: 0.978

# %%
# Q.35: Write a Python program to perform feature selection before training a Naïve Bayes classifier and compare results
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import accuracy_score

# Load dataset
X, y = load_iris(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Naive Bayes without feature selection
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
y_pred = nb_model.predict(X_test)
acc_full = accuracy_score(y_test, y_pred)

# Feature selection: Select top 2 features
selector = SelectKBest(score_func=f_classif, k=2)
X_train_selected = selector.fit_transform(X_train, y_train)
X_test_selected = selector.transform(X_test)

# Train Naive Bayes with selected features
nb_model_selected = GaussianNB()
nb_model_selected.fit(X_train_selected, y_train)
y_pred_selected = nb_model_selected.predict(X_test_selected)
acc_selected = accuracy_score(y_test, y_pred_selected)

# Compare results
print(f"Accuracy without feature selection: {acc_full:.3f}")
print(f"Accuracy with feature selection: {acc_selected:.3f}")
# Out:
# Accuracy without feature selection: 0.978
# Accuracy with feature selection: 1.000

# %%
# Q.36:Write a Python program to train an SVM Classifier using One-vs-Rest (OvR) and One-vs-One (OvO) strategies on the Wine dataset and compare their accuracy
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from sklearn.metrics import accuracy_score

# Load Wine dataset
X, y = datasets.load_wine(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# One-vs-Rest SVM
ovr_model = OneVsRestClassifier(SVC(kernel='linear'))
ovr_model.fit(X_train, y_train)
y_pred_ovr = ovr_model.predict(X_test)
ovr_acc = accuracy_score(y_test, y_pred_ovr)

# One-vs-One SVM
ovo_model = OneVsOneClassifier(SVC(kernel='linear'))
ovo_model.fit(X_train, y_train)
y_pred_ovo = ovo_model.predict(X_test)
ovo_acc = accuracy_score(y_test, y_pred_ovo)

# Compare accuracies
print(f"One-vs-Rest Accuracy: {ovr_acc:.3f}")
print(f"One-vs-One Accuracy: {ovo_acc:.3f}")
# Out:
# One-vs-Rest Accuracy: 0.981
# One-vs-One Accuracy: 0.981

# %%
# Q.37:Write a Python program to train an SVM Classifier using Linear, Polynomial, and RBF kernels on the Breast Cancer dataset and compare their accuracy
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load Breast Cancer dataset
X, y = load_breast_cancer(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define kernels
kernels = ['linear', 'poly', 'rbf']
accuracies = {}

for kernel in kernels:
    model = SVC(kernel=kernel)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    accuracies[kernel] = acc

# Compare accuracies
for kernel, acc in accuracies.items():
    print(f"{kernel.capitalize()} kernel Accuracy: {acc:.3f}")
# Out:
# Linear kernel Accuracy: 0.965
# Poly kernel Accuracy: 0.942
# Rbf kernel Accuracy: 0.936

# %%
# Q.38: Write a Python program to train an SVM Classifier using Stratified K-Fold Cross-Validation and compute the average accuracy
from sklearn.datasets import load_iris
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.svm import SVC
import numpy as np

# Load dataset
X, y = load_iris(return_X_y=True)

# Define SVM model
model = SVC(kernel='linear')

# Stratified K-Fold Cross-Validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(model, X, y, cv=skf)

# Compute average accuracy
average_accuracy = np.mean(scores)
print(f"Cross-Validation Accuracies: {scores}")
print(f"Average Accuracy: {average_accuracy:.3f}")
# Out:
# Cross-Validation Accuracies: [1.         1.         0.93333333 1.         1.        ]
# Average Accuracy: 0.987

# %%
# Q.39: Write a Python program to train a Naïve Bayes classifier using different prior probabilities and compare performance
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Load dataset
X, y = load_iris(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Different prior probabilities
priors_list = [None, [0.5, 0.25, 0.25], [0.33, 0.33, 0.34]]

for priors in priors_list:
    model = GaussianNB(priors=priors)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print(f"Priors: {priors}, Accuracy: {acc:.3f}")
# Out:
# Priors: None, Accuracy: 0.978
# Priors: [0.5, 0.25, 0.25], Accuracy: 0.978
# Priors: [0.33, 0.33, 0.34], Accuracy: 0.978

# %%
# Q.40: Write a Python program to perform Recursive Feature Elimination (RFE) before training an SVM Classifier and compare accuracy
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.feature_selection import RFE
from sklearn.metrics import accuracy_score

# Load dataset
X, y = load_iris(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train SVM without feature selection
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)
acc_full = accuracy_score(y_test, y_pred)

# Perform Recursive Feature Elimination (RFE)
rfe = RFE(estimator=SVC(kernel='linear'), n_features_to_select=2)
X_train_rfe = rfe.fit_transform(X_train, y_train)
X_test_rfe = rfe.transform(X_test)

# Train SVM with selected features
svm_rfe_model = SVC(kernel='linear')
svm_rfe_model.fit(X_train_rfe, y_train)
y_pred_rfe = svm_rfe_model.predict(X_test_rfe)
acc_rfe = accuracy_score(y_test, y_pred_rfe)

# Compare accuracies
print(f"Accuracy without RFE: {acc_full:.3f}")
print(f"Accuracy with RFE: {acc_rfe:.3f}")
# Out:
# Accuracy without RFE: 1.000
# Accuracy with RFE: 1.000

# %%
# Q.41:Write a Python program to train an SVM Classifier and evaluate its performance using Precision, Recall, and F1-Score instead of accuracy
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Load dataset
X, y = load_iris(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train SVM classifier
model = SVC(kernel='linear')
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate using Precision, Recall, F1-Score
report = classification_report(y_test, y_pred, target_names=['Class 0', 'Class 1', 'Class 2'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00        19
#      Class 1       1.00      1.00      1.00        13
#      Class 2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# Q.42:Write a Python program to train a Naïve Bayes Classifier and evaluate its performance using Log Loss (Cross-Entropy Loss)
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import log_loss

# Load dataset
X, y = load_iris(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Naive Bayes classifier
model = GaussianNB()
model.fit(X_train, y_train)

# Predict probabilities
y_prob = model.predict_proba(X_test)

# Evaluate using Log Loss
loss = log_loss(y_test, y_prob)
print(f"Log Loss (Cross-Entropy Loss): {loss:.3f}")
# Out:
# Log Loss (Cross-Entropy Loss): 0.049

# %%
# Q.43: Write a Python program to train an SVM Classifier and visualize the Confusion Matrix using seaborn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix

# Load dataset
X, y = load_iris(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train SVM classifier
model = SVC(kernel='linear')
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Visualize using seaborn
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Setosa','Versicolor','Virginica'], yticklabels=['Setosa','Versicolor','Virginica'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for SVM Classifier')
plt.show()

# %%
# Q.44:Write a Python program to train an SVM Regressor (SVR) and evaluate its performance using Mean Absolute Error (MAE) instead of MSE
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error

# Load dataset
X, y = fetch_california_housing(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train SVR model
model = SVR(kernel='rbf')
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate using Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error (MAE): {mae:.3f}")
# Out:
# Mean Absolute Error (MAE): 0.866

# %%
# Q.45: Write a Python program to train a Naïve Bayes classifier and evaluate its performance using the ROC-AUC score
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Load dataset
X, y = load_breast_cancer(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Naive Bayes classifier
model = GaussianNB()
model.fit(X_train, y_train)

# Predict probabilities
y_prob = model.predict_proba(X_test)[:, 1]

# Evaluate using ROC-AUC Score
roc_auc = roc_auc_score(y_test, y_prob)
print(f"ROC-AUC Score: {roc_auc:.3f}")

# Plot ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_prob)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Naive Bayes Classifier')
plt.legend()
plt.show()
# Out:
# ROC-AUC Score: 0.992

# %%
#Q.46: Write a Python program to train an SVM Classifier and visualize the Precision-Recall Curve.
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Load dataset
X, y = load_breast_cancer(return_X_y=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train SVM classifier with probability=True to get prediction probabilities
model = SVC(kernel='rbf', probability=True)
model.fit(X_train, y_train)

# Predict probabilities
y_prob = model.predict_proba(X_test)[:, 1]

# Calculate Precision and Recall
precision, recall, _ = precision_recall_curve(y_test, y_prob)
avg_precision = average_precision_score(y_test, y_prob)

# Plot Precision-Recall Curve
plt.plot(recall, precision, label=f'AP = {avg_precision:.3f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for SVM Classifier')
plt.legend()
plt.show()
